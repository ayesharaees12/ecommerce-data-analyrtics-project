# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import pandas as pd

# %% [markdown]
# **LOAD THE DATASET**

# %%
df=pd.read_excel("/content/Dataset for Data Analytics.xlsx")

# %% [markdown]
# Check First 5 Columns

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %% [markdown]
# Null Values Check

# %%
df.isnull().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %% [markdown]
# Dupliacted Values Check

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Length: 1200, dtype: bool

# %% [markdown]
# Shape Of Dataset

# %%
df.shape
# Out:
# (1200, 14)

# %% [markdown]
# Total Number Of Unique values IN ORDERID

# %%
df["OrderID"].nunique()
# Out:
# 1200

# %% [markdown]
# Checking  Values Counts Of Product And Quantity

# %%
df[["Product","Quantity"]].value_counts()
# Out:
# Product  Quantity
# Chair    3           47
# Phone    1           44
# Tablet   1           43
# Laptop   4           42
# Chair    4           41
# Printer  4           41
# Phone    2           40
# Tablet   2           40
# Laptop   5           39
# Printer  3           39
# Tablet   3           38
# Desk     1           38
# Laptop   2           36
# Desk     4           36
# Printer  2           36
# Desk     3           35
# Chair    5           35
# Printer  1           34
# Laptop   1           34
# Monitor  1           34
#          3           34
# Desk     5           33
# Monitor  2           33
#          4           32
# Printer  5           31
# Tablet   4           30
# Monitor  5           30
# Phone    4           29
# Chair    1           28
# Tablet   5           28
# Desk     2           28
# Chair    2           27
# Laptop   3           22
# Phone    3           22
#          5           21
# Name: count, dtype: int64

# %% [markdown]
# Filling Null values Of CouponCode With "No Coupon"

# %%
df["CouponCode"]=df["CouponCode"].fillna("No Coupon")

# %% [markdown]
# Now Checking there is no null values

# %%
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# CustomerID         0
# Product            0
# Quantity           0
# UnitPrice          0
# ShippingAddress    0
# PaymentMethod      0
# OrderStatus        0
# TrackingNumber     0
# ItemsInCart        0
# CouponCode         0
# ReferralSource     0
# TotalPrice         0
# dtype: int64

# %% [markdown]
# Checking Unique Values

# %%
df["Product"].unique()
# Out:
# array(['Monitor', 'Phone', 'Tablet', 'Chair', 'Printer', 'Laptop', 'Desk'],
#       dtype=object)

# %%
df["PaymentMethod"].unique()
# Out:
# array(['Debit Card', 'Online', 'Credit Card', 'Gift Card', 'Cash'],
#       dtype=object)

# %%
df["ReferralSource"].unique()
# Out:
# array(['Instagram', 'Referral', 'Email', 'Facebook', 'Google'],
#       dtype=object)

# %%
df["OrderStatus"].unique()
# Out:
# array(['Shipped', 'Cancelled', 'Returned', 'Delivered', 'Pending'],
#       dtype=object)

# %%
df["TrackingNumber"].unique()
# Out:
# array(['TRK37947903', 'TRK91186779', 'TRK42903982', ..., 'TRK88039356',
#        'TRK71683331', 'TRK51116746'], dtype=object)

# %%
df["ShippingAddress"].unique()
# Out:
# array(['928 Main St', '823 Main St', '512 Main St', '275 Main St',
#        '668 Main St', '934 Main St', '986 Main St', '706 Main St',
#        '904 Main St', '102 Main St', '333 Main St', '831 Main St',
#        '179 Main St', '903 Main St', '980 Main St', '942 Main St',
#        '914 Main St', '382 Main St', '891 Main St', '273 Main St',
#        '587 Main St', '569 Main St', '633 Main St', '755 Main St',
#        '956 Main St', '709 Main St', '296 Main St', '881 Main St',
#        '568 Main St', '930 Main St', '895 Main St', '996 Main St',
#        '830 Main St', '912 Main St', '926 Main St', '128 Main St',
#        '465 Main St', '409 Main St', '549 Main St', '666 Main St',
#        '267 Main St', '657 Main St', '871 Main St', '157 Main St',
#        '223 Main St', '323 Main St', '464 Main St', '446 Main St',
#        '434 Main St', '232 Main St', '623 Main St', '565 Main St',
#        '566 Main St', '842 Main St', '202 Main St', '811 Main St',
# ...

# %% [markdown]
# Extra Spaces Check For Product Column

# %%
df["Product"].str.strip().equals(df["Product"])
# Out:
# True

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df.to_excel("cleaned_data.xlsx",index=False)
